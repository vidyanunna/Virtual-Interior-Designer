# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40afd042-6475-41ff-a342-01f285a74a75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40afd042-6475-41ff-a342-01f285a74a75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip Virtual\ Interior\ Designer.zip
# Out:
# Archive:  Virtual Interior Designer.zip
#    creating: Virtual Interior Designer/
#   inflating: Virtual Interior Designer/app.py
#   inflating: Virtual Interior Designer/Copy_of_Virtual_Interior_Designer_with_GAN.ipynb
#   inflating: Virtual Interior Designer/full_room.ipynb
#   inflating: Virtual Interior Designer/full_room.py
#   inflating: Virtual Interior Designer/GAN.ipynb
#    creating: Virtual Interior Designer/static/
#   inflating: Virtual Interior Designer/static/styles.css
#    creating: Virtual Interior Designer/templates/
#   inflating: Virtual Interior Designer/templates/bathroom.html
#   inflating: Virtual Interior Designer/templates/bedroom.html
#   inflating: Virtual Interior Designer/templates/index.html
#   inflating: Virtual Interior Designer/templates/kitchen.html
#   inflating: Virtual Interior Designer/templates/living-room.html
#   inflating: Virtual Interior Designer/templates/page2.html
#   inflating: Virtual Interior Designer/templates/page3.html
# ...

# %%
# !pip install flask diffusers transformers accelerate safetensors torch torchvision pillow realesrgan
# !pip uninstall basicsr -y
# !pip install git+https://github.com/xinntao/BasicSR.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# ...

# %%
# %cd "/content/Virtual Interior Designer"
# Out:
# /content/Virtual Interior Designer

# %%
pip install flask flask-ngrok diffusers transformers accelerate safetensors torch torchvision pillow

# %%
pip install flask pyngrok diffusers transformers accelerate safetensors torch torchvision pillow

# %%
# !python app.py
# Out:
# 2025-02-24 05:52:28.193738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740376348.214279    1843 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740376348.220727    1843 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model_index.json: 100% 543/543 [00:00<00:00, 3.73MB/s]
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# scheduler%2Fscheduler_config.json: 100% 346/346 [00:00<00:00, 2.67MB/s]
#
# tokenizer%2Fvocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# tokenizer%2Fmerges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# ...
